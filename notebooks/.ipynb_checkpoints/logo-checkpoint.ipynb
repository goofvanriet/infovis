# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Laad de afbeelding
img = mpimg.imread('../data/logo_infovis.png')

# Maak een figuur en een subplot
fig, ax = plt.subplots(figsize=(3, 3))  # Pas de figsize aan om de grootte van de afbeelding te veranderen
ax.imshow(img)
ax.axis('off')  # Verberg de as
ax.set_frame_on(False)  # Verberg de frame rand

# Verwijder alle marges
fig.subplots_adjust(left=0, right=1, top=1, bottom=0, wspace=0, hspace=0)

# Zorg dat de layout van de figuur strak is, zonder extra padding
fig.tight_layout(pad=0)

# Toon de afbeelding
plt.show()
